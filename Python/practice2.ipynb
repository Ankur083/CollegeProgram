# %%
list=[]
n=int(input("enter a value"))
for i in range(n): 
     ele=(input("enter a value:"))
     list.append(ele)
     print(list)
first=list[0]
list[0]=list[n-1]
list[n-1]=first
print(list)
# Out:
# enter a value 5
# enter a value: a
# ['a']
# enter a value: b
# ['a', 'b']
# enter a value: c
# ['a', 'b', 'c']
# enter a value: d
# ['a', 'b', 'c', 'd']
# enter a value: e
# ['a', 'b', 'c', 'd', 'e']
# ['e', 'b', 'c', 'd', 'a']

# %%
list=[]
n=int(input("enter a number"))
for i in range(n):
    ele=int(input("enter a number"))
    list.append(ele)
    print(list)
second=list[1]
list[1]=list[n-2]
list[n-2]=second
third=list[2]
list[2]=list[n-3]
list[n-3]=third
print(list)
# Out:
# enter a number 8
# enter a number 89
# [89]
# enter a number 98
# [89, 98]
# enter a number 78
# [89, 98, 78]
# enter a number 45
# [89, 98, 78, 45]
# enter a number 34
# [89, 98, 78, 45, 34]
# enter a number 23
# [89, 98, 78, 45, 34, 23]
# enter a number 12
# [89, 98, 78, 45, 34, 23, 12]
# enter a number 16
# [89, 98, 78, 45, 34, 23, 12, 16]
# [89, 12, 23, 45, 34, 78, 98, 16]

# %%
list=[1,32,34,43,344,45,26]
print(len(list))
# Out:
# 7

# %%
list=[]
for i in range(2):
    ele=int(input("enter a number"))
    list.append(ele)
    print(list)
if(list[0]>list[1]):
    print(f"{list[0]} is max")
else:
    print(f"{list[1]} is max")
# Out:
# enter a number 45
# [45]
# enter a number 67
# [45, 67]
# 67 is max

# %%
list=[2,3,45,4,7]
i=67
if i in list:
    print("exist")
else:
      print("not exist ")
# Out:
# not exist

# %%
list=[23,34,67,78,89]
list.clear()
print(list)
# Out:
# []

# %%
list=[34,23,12,78,31]
list.sort()
list.reverse()
print(list)
# Out:
# [78, 34, 31, 23, 12]

# %%
list=[23,34,45,56,67]
list1=list.copy()
print(list1)
# Out:
# [23, 34, 45, 56, 67]

# %%
for i in range(0,5):
    s = ""
    for j in range(5,i,-1):
         s+="*"
    print(s)
# Out:
# *****
# ****
# ***
# **
# *

# %%
print(type(range(3)))
# Out:
# <class 'range'>

# %%
i=8
x=f"hello {'hi'}"
print(x)
# Out:
# hello hi

# %%
for i in range(3):
    print(i)
    i=10
# Out:
# 0
# 1
# 2

# %%
for i in [1,2,3,4,{k}]:
    print(i)
    i=10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 for i in [1,2,3,4,k]:
#       2     print(i)
#       3     i=10
#
# NameError: name 'k' is not defined

# %%
 li = [1,3,2,4,5,7,9]

# %%
li.append(2)

# %%
li
# Out:
# [1, 3, 2, 4, 5, 7, 9, 2]

# %%
li.insert(0,22)

# %%
li
# Out:
# [22, 1, 3, 2, 4, 5, 7, 9, 2]

# %%
len(li)
# Out:
# 9

# %% [markdown]
# ## Removing and deleting
# <li>we will learn to remove and delete items of a list</li>

# %%
li
# Out:
# [22, 1, 3, 2, 4, 5, 7, 9, 2]

# %%
li.remove(1)
print(li)
# Out:
# [22, 3, 2, 4, 5, 7, 9, 2]

# %%
li.remove(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 li.remove(1)
#
# ValueError: list.remove(x): x not in list

# %%
li.remove(2)
li
# Out:
# [22, 3, 4, 5, 7, 9, 2]

# %%
li.pop()
li
# Out:
# [22, 3, 4, 5, 7, 9]

# %%
li.pop(0)
li
# Out:
# [3, 4, 5, 7, 9]

# %%
del li[1:3]
print(li)
# Out:
# [3, 7, 9]

# %%
li.insert(0,8)
li.insert(3,2)
li
# Out:
# [8, 3, 7, 2, 9]

# %%
li.sort()
li
# Out:
# [2, 3, 7, 8, 9]

# %%
print(li[3:])
# Out:
# [8, 9]

# %% [markdown]
# ###
# string slicing, follows 3 steps - start : stop : steps
# but stop will always be stop - 1

# %%
li
# Out:
# [2, 3, 7, 8, 9]

# %%
print(li[::-1])
# Out:
# [9, 8, 7, 3, 2]

# %%
li.reverse()
li
# Out:
# [2, 3, 7, 8, 9]

# %%
print(li[0::2])
# Out:
# [2, 7, 9]

# %%
li
# Out:
# [2, 3, 7, 8, 9]

# %%
li.extend([10,11,3,6,7])

# %%
li
# Out:
# [2, 3, 7, 8, 9, 10, 11, 3, 6, 7]

# %% [markdown]
# ## Tuple

# %%
my_tup = (1,2,3,4)

# %% [markdown]
# ## Dictionary

# %%
my_dict = {"name":"ankur","age":21}

# %%
my_dict
# Out:
# {'name': 'ankur', 'age': 21}

# %%
my_dict["loc"] = "NIT"

# %%
list(my_dict.keys())
# Out:
# ['name', 'age', 'loc']

# %%
my_dict.items()
# Out:
# dict_items([('name', 'ankur'), ('age', 21), ('loc', 'NIT')])

# %%
for key,value in my_dict.items():
    print(key,value)
# Out:
# name ankur
# age 21
# loc NIT

# %%
set1 = {5,6,1,8,2,6}

# %%
print(set1)
# Out:
# {1, 2, 5, 6, 8}

# %%
set1.remove(2)
set1
# Out:
# {1, 5, 6, 8}

# %%
set1.remove(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 set1.remove(2)
#
# KeyError: 2

# %%
set1.discard(2)

# %%
age = 20
status = "adult" if age>= 18 else "minor"
print(status)
# Out:
# adult

# %%
8
# Out:
# 8

# %%
import pandas as pd
# Create a DataFrame
data={
    'Name':['Alice','Bob','Charlie','David','Eve'],
    'Age':[25,32,45,28,30],
    'Salary':[50000,62000,58000,60000,65000]
}
df=Pd.DataFrame(data)

# Display the DataFrame
print("DataFrame:")
print(df)

# Apply aggregation functions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       2 # Create a DataFrame
#       3 data={
#       4     'Name':['Alice','Bob','Charlie','David','Eve'],
#       5     'Age':[25,32,45,28,30],
#       6     'Salary':[50000,62000,58000,60000,65000]
#       7 }
# ----> 8 df=Pd.DataFrame(data)
#      10 # Display the DataFrame
#      11 print("DataFrame:")
#
# NameError: name 'Pd' is not defined
