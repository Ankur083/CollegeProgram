# %%
#wap to input 2 int numbers ,a and b print True if agreater than equal
#to b.if not print false
a=int(input("enter a number a:"))
b=int(input("enter a number b:"))
print(a>=b)
# Out:
# enter a number a: 98
# enter a number b: 87
# True

# %%
list=["five","four","three","two","one","no","he","none"]
for i in range(6):
    
 print(f"{list[i]} little monkeys jumping on the bed")
 if i<4 :i=4
 elif i==5:i=7
 else :i=6
 print(f"{list[i]} fell down one bumped his head")
 print("Mama called the doctor and the doctor said ")
 print("No more monkeys jumping on the bed") 
 print("\n")
# Out:
# five little monkeys jumping on the bed
# one fell down one bumped his head
# Mama called the doctor and the doctor said
# No more monkeys jumping on the bed
#
#
# four little monkeys jumping on the bed
# one fell down one bumped his head
# Mama called the doctor and the doctor said
# No more monkeys jumping on the bed
#
#
# three little monkeys jumping on the bed
# one fell down one bumped his head
# Mama called the doctor and the doctor said
# No more monkeys jumping on the bed
#
#
# two little monkeys jumping on the bed
# one fell down one bumped his head
# Mama called the doctor and the doctor said
# No more monkeys jumping on the bed
#
#
# one little monkeys jumping on the bed
# he fell down one bumped his head
# Mama called the doctor and the doctor said
# No more monkeys jumping on the bed
#
#
# no little monkeys jumping on the bed
# none fell down one bumped his head
# Mama called the doctor and the doctor said
# No more monkeys jumping on the bed

# %%
import re
greedyHaRegex = re.compile(r'(Ha){3,5}')
mo1 = greedyHaRegex.search('HaHa')
print(mo1)
# Out:
# None

# %%
nongreedyHaRegex = re.compile(r'(Ha){3,5}?')
mo2 = nongreedyHaRegex.search('HaHaHaHaHa')
print(mo2.group())
# Out:
# HaHaHa

# %%
import pyinputplus as pyip
response = pyip.inputNum('>', min=4, lessThan=6)
# Out:
# >
#  3
# Number must be at minimum 4.
# >
#  6
# Number must be less than 6.
# >
#  5

# %%
import pyinputplus as pyip
response = pyip.inputNum('Enter num: ')
# Out:
# Enter num:
# Blank values are not allowed.
# Enter num:
#  44

# %%
response = pyip.inputNum(blank=True)

# %%
import re
pattern = re.compile(r'Bat(wo)?man')
match1 = pattern.search('The Adventures of Batman')
match2 = pattern.search('The Adventures of Batwoman')
print(match1.group())
print(match2.group())
# Out:
# Batman
# Batwoman

# %%
import re
pattern = re.compile(r'\d+')
matches = pattern.findall('There are 123 apples and 45 bananas.')
print(matches)
# Out:
# ['123', '45']

# %%
import re
pattern = re.compile(r'^Hello')
match = pattern.search('Hello world!')
print(match.group())
# Out:
# Hello

# %%
import re
pattern = re.compile(r'\d{3}-\d{2}-\d{4}')
match = pattern.fullmatch('123-45-6789')
print(match.group())
# Out:
# 123-45-6789

# %%
def is_valid_email(email):
    import re
    pattern = re.compile(r'^\w+@\w+\.\w+$')
    return pattern.match(email) is not None

print(is_valid_email('user@example.com'))
print(is_valid_email('user@example'))
# Out:
# True
# False

# %%
import re
pattern = re.compile(r'\s+')
matches = pattern.split('Hello     world!')
print(matches)
# Out:
# ['Hello', 'world!']

# %%
import re
pattern = re.compile(r'\d+')
result = pattern.sub('X', 'There are 123 apples and 45 bananas.')
print(result)
# Out:
# There are X apples and X bananas.

# %%
import re
pattern = re.compile(r'(\d{3})-(\d{3})-(\d{4})')
match = pattern.search('My number is 415-555-4242.')
print(match.group(1))
print(match.group(2))
print(match.group(3))
# Out:
# 415
# 555
# 4242

# %%
import re
pattern = re.compile(r'(\d+)+')
matches = pattern.findall('123 456 789')
print(matches)
# Out:
# ['123', '456', '789']

# %%
import re
pattern = re.compile(r'<.*>')
match = pattern.search('<html><head></head></html>')
print(match.group())
# Out:
# <html><head></head></html>

# %%
import re
pattern = re.compile(r'<.*?>')
match = pattern.search('<html><head></head></html>')
print(match.group())
# Out:
# <html>

# %%
import re
def extract_phone_numbers(text):
    pattern = re.compile(r'\d{3}-\d{3}-\d{4}')
    return pattern.findall(text)

print(extract_phone_numbers('Call me at 415-555-4242 or 212-555-0000'))
# Out:
# ['415-555-4242', '212-555-0000']

# %%
import re
pattern = re.compile(r'\d+\.\d*')
match = pattern.search('The price is 12.99 dollars.')
print(match.group())
# Out:
# 12.99

# %%
import re
pattern = re.compile(r'\b\w+\b')
matches = pattern.findall('This is a test.')
print(matches)
# Out:
# ['This', 'is', 'a', 'test']

# %%
import re
pattern = re.compile(r'(\d{1,3}\.){3}\d{1,3}')
match = pattern.search('My IP address is 192.168.0.1.')
print(match.group())
# Out:
# 192.168.0.1

# %%
phoneNumRegex = re.compile(r'\d\d\d-\d\d\d-\d\d\d\d')
phoneNumRegex.sub('XXX-XXX-XXXX', 'My number is 415-555-4242.')
# Out:
# 'My number is XXX-XXX-XXXX.'

# %%
def string_manipulation(text):
    return text[::-1].upper()

print(string_manipulation("Automate the Boring Stuff"))
# Out:
# FFUTS GNIROB EHT ETAMOTUA

# %%
import re
pattern = re.compile(r'(\d{1,3}\.){3}\d{1,3}')
match = pattern.search('My IP address is 192.168.0.1.')
print(match.group())
# Out:
# 192.168.0.1

# %%
import re
pattern = re.compile(r'\d+\.\d+')
match = pattern.search('The price is 12. dollars.')
print(match.group())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 4
#       2 pattern = re.compile(r'\d+\.\d+')
#       3 match = pattern.search('The price is 12. dollars.')
# ----> 4 print(match.group())
#
# AttributeError: 'NoneType' object has no attribute 'group'
