# %%
marks=[94.4,87.5,95.2,66.4,45.1]
print(marks)
print(type(marks))
print(len(marks))  
print(marks[0])
print(marks[1])
# Out:
# [94.4, 87.5, 95.2, 66.4, 45.1]
# <class 'list'>
# 5
# 94.4
# 87.5

# %%
 student=["karan",95.4,85,"delhi"]
 print(student)
# Out:
# ['karan', 95.4, 85, 'delhi']

# %%
 student=["karan",95.4,85,"delhi"]
 print(student)
 student[0]="arjun"
 print(student)
# Out:
# ['karan', 95.4, 85, 'delhi']
# ['arjun', 95.4, 85, 'delhi']

# %%
 student=["karan",95.4,85,"delhi"]
 print(student[1:3])
# Out:
# [95.4, 85]

# %%
# list methods
list=[2,1,3]
list.append(4)#add one elements at the end  
print(list)
# Out:
# [2, 1, 3, 4]

# %%
list=[2,1,3]
list.sort()#sorts in ascending order
print(list)
# Out:
# [1, 2, 3]

# %%
list=[2,1,3]
list.sort(reverse=True)#sorts in descending order
print(list)
# Out:
# [3, 2, 1]

# %%
list=[2,1,3]
list.reverse()#reverse list
print(list)
# Out:
# [3, 1, 2]

# %%
list=[2,1,3]
list.insert(0,4)#insert element at index
print(list)
# Out:
# [4, 2, 1, 3]

# %%
list=[2,1,3]
print(list.append(4))
# print(list.sort())
# print(list)
# Out:
# None

# %%
list=['a','d','e','f','c','b']
print(list.sort())
print(list)
# Out:
# None
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
list=["banana","litchi","apple"]
print(list.append("mango"))
print(list.sort())
print(list)
# Out:
# None
# None
# ['apple', 'banana', 'litchi', 'mango']

# %%
list=[2,1,3,1]
list.remove(2)
print(list)
# Out:
# [1, 3, 1]

# %%
list=[2,1,3,1]
list.pop(0)
print(list)
# Out:
# [1, 3, 1]

# %%
#tuple
tup=(2,1,3,1)
print(type(tup))
print(tup[0])
print(tup[1])
# Out:
# <class 'tuple'>
# 2
# 1

# %%
tup=(1,)
print(tup)
print(type(tup))
# Out:
# (1,)
# <class 'tuple'>

# %%
tup=(1.0,)
print(tup)
print(type(tup))
# Out:
# (1.0,)
# <class 'tuple'>

# %%
tup=("hello",)
print(tup)
print(type(tup))
# Out:
# ('hello',)
# <class 'tuple'>

# %%
tup=(1,2,3,4)
print(tup[1:4])
# Out:
# (2, 3, 4)

# %%
#tupple methods
tup=(2,3,1,4)
tup.index(el)#2

# %%
tup=(1,2,3,4)
print(tup.index(2))
# Out:
# 1

# %%
tup=(1,2,3,4,2,2)
print(tup.count(2))
# Out:
# 3

# %%
# Out:
#   Cell In[7], line 2
#     if (c % 2 ==  and c % c == 0):
#                   ^
# SyntaxError: invalid syntax
