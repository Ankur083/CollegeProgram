# %%
info={
    "name":"apnacollege",
    "subjects":["python","java","c"],
    "topics":("dict","set"),
    "age":34,
    "is adult":True,
    12.99:94.4
}

print(info["name"])
# Out:
# apnacollege

# %%
info={
    "name":"apnacollege",
    "subjects":["python","java","c"],
    "topics":("dict","set"),
    "age":34,
    "is adult":True,
    12.99:94.4
}
print(info)
# Out:
# {'name': 'apnacollege', 'subjects': ['python', 'java', 'c'], 'topics': ('dict', 'set'), 'age': 34, 'is adult': True, 12.99: 94.4}

# %%
info={
    "name":"apnacollege",
    "subjects":["python","java","c"],
    "topics":("dict","set"),
    "age":34,
    "is adult":True,
    12.99:94.4
}
info["name"]="Ankur"
info["surname"]="raj"
print(info)
# Out:
# {'name': 'Ankur', 'subjects': ['python', 'java', 'c'], 'topics': ('dict', 'set'), 'age': 34, 'is adult': True, 12.99: 94.4, 'surname': 'raj'}

# %%
null_dict
null_dict["name"]="ankur"
print(null_dict)
# Out:
# {'name': 'ankur'}

# %%
#nested dictionary
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(student["score"]["chem"])
# Out:
# 95

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(student)
# Out:
# {'name': 'ankur raj', 'score': {'chem': 95, 'phy': 97, 'math': 99}}

# %%
#dictionary method
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(student.keys())
# Out:
# dict_keys(['name', 'score'])

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(list(student.keys()))
# Out:
# ['name', 'score']

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(len(list(student.keys())))
# Out:
# 2

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(student.values())
# Out:
# dict_values(['ankur raj', {'chem': 95, 'phy': 97, 'math': 99}])

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(list(student.items()))
# Out:
# [('name', 'ankur raj'), ('score', {'chem': 95, 'phy': 97, 'math': 99})]

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(student.items())
# Out:
# dict_items([('name', 'ankur raj'), ('score', {'chem': 95, 'phy': 97, 'math': 99})])

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }

}
pairs=list(student.items())
print(pairs[0])
# Out:
# ('name', 'ankur raj')

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(student.get("name"))
# Out:
# ankur raj

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
print(student["name2"])#error
print(student.get("name2"))#no error->none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 9
#       1 student={
#       2     "name":"ankur raj",
#       3     "score":{
#    (...)
#       7      }
#       8 }
# ----> 9 print(student[name2])
#      10 print(student.get("name2"))
#
# NameError: name 'name2' is not defined

# %%
student={
    "name":"ankur raj",
    "score":{
         "chem":95,
         "phy":97,
         "math":99,
     }
}
new_dict={"name":"neha kumari","age":16}
student.update(new_dict)
print(student)
# Out:
# {'name': 'neha kumari', 'score': {'chem': 95, 'phy': 97, 'math': 99}, 'age': 16}

# %%
# sets in python
collection={1,2,2,2,"hello","world","world",4}
print(collection)
print(len(collection))#total number of item
# Out:
# {1, 2, 4, 'hello', 'world'}
# 5

# %%
#collection={}#empty dictionary
collection=set()#empty set;syntax
print(type(collection))
# Out:
# <class 'set'>

# %%
# set methods
num={1,2,3,4,5}
num.add(6)
print(num)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
num={1,2,3,4,5}
num.remove(5)
print(num)
# Out:
# {1, 2, 3, 4}

# %%
collection=set()
collection.add(1)
collection.add(2)
collection.add("apnacollege")
collection.add((1,2,3))
print(len(collection))
print(collection)
# Out:
# 4
# {1, 2, (1, 2, 3), 'apnacollege'}

# %%
collection=set()
collection.add(1)
collection.add(2)
collection.add("apnacollege")
collection.add((1,2,3))
print(len(collection))
print(collection)
collection.clear()
print(len(collection))
# Out:
# 4
# {1, 2, (1, 2, 3), 'apnacollege'}
# 0

# %%
collection={"hello","apnacollege","world","coding","python"}
print(collection.pop())
print(collection.pop())
# Out:
# python
# hello

# %%
set1={1,2,3}
set2={2,3,4}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4}

# %%
set1={1,2,3}
set2={2,3,4}
print(set1.intersection(set2))
# Out:
# {2, 3}
