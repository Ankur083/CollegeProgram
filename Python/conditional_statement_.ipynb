# %%
age=int(input("enter a age"))
if(age>=18):
   print("can vote & apply for liscense")
else:
    print("can not vote & not apply for liscense")
# Out:
# enter a age 18
# can vote & apply for liscense

# %%
light=input("enter a colour of light:")
if(light=="green"):
     print("go")
elif(light=="red"):
    print("stop")
elif(light=="yellow"):
    print("wait")
else:
    print("thank you")
# Out:
# enter a colour of light: blue
# thank you

# %%
age = 24

if(age>=18):
      print("can vote")#indentation
else:
    print("cannot vote")
# Out:
# can vote

# %%
marks=int(input("enter a marks:"))

if(marks>=90):
    print("grade=A" )
elif(marks>=80 and marks<90):
    print("grade=B")
elif(marks>=70 and marks<80):
    print("grade=C")
else:
    print("grade=D")
# Out:
# enter a marks: 60
# grade=D

# %%
age=95

if(age>=18):
    if(age >=80):
        print("cannot drive")
    else:
        print("can drive")
else:
    print("cannot drive")
# Out:
# cannot drive

# %%
if(2>4):
    print("hello")
    if(3<5):
            print("hi")

if(2>4):
    print("hello")
if(3<5):
    print("hi")
# Out:
# hi
