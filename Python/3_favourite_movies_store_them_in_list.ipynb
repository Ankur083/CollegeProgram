# %%
movies=[]
first =input("enter a first movie:")
second =input("enter a second movie:")
third =input("enter a third movie:")


movies.append(first)
movies.append(second)
movies.append(third)
print(movies)
# Out:
# enter a first movie: pk
# enter a second movie: fann
# enter a third movie: 1920
# ['pk', 'fann', '1920']
