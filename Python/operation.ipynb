# %%
# arthmetic operator
a=5
b=2 

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)#remainder
print(a**b)#a^b
# Out:
# 7
# 3
# 10
# 2.5
# 1
# 25

# %%
#relation/comparison operator
a=50
b=20

print(a==b)
print(a!=b)
print(a>=b)
print(a>b)
print(a<=b)
print(a<b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
# assignment operator
num = 10
num += 10
print("num:",num)
# Out:
# num: 20

# %%
num =10
num -=10
print("num:",num)
# Out:
# num: 0

# %%
num=10
num *=10
print("num:",num)
# Out:
# num: 100

# %%
num=10
num /=10
print("num:",num)
# Out:
# num: 1.0

# %%
num=10
num%=10
print("num:",num)
# Out:
# num: 0

# %%
num=2
num**=5
print("num:",num)
# Out:
# num: 32

# %%
#logical operator
a=50
b=30
print(not(a>b))
# Out:
# False

# %%
val1=True
val2=False
print("AND operator:",val1 and val2)
# Out:
# AND operator: False

# %%
val1=False
val2=True
print("OR operator:",(val1) or (val2))
# Out:
# OR operator: True
